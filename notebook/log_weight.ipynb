# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
x = np.arange(1, 11)
y = 1 / np.log2(x + 1)
plt.figure(figsize=(12, 6))
plt.plot(x, y)
plt.xlabel("rank")
plt.ylabel("weight")
plt.tight_layout()
plt.show()
